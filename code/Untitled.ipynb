# %%
import pandas as pd
import numpy as np

# %%
category_file = "../data/bgg_Category.csv"
type_file = "../data/bgg_GameType.csv"
mechanic_file = "../data/bgg_Mechanic.csv"

# %%
category_df = pd.read_csv(category_file)
category_df.head()
# Out:
#    bgg_id               name
# 0    1001          Political
# 1    1002          Card Game
# 2    1008           Nautical
# 3    1009  Abstract Strategy
# 4    1010            Fantasy

# %%
category_df = category_df.rename(columns={'bgg_id':'category_id','name':'category_name'})
category_df.head()
# Out:
#    category_id      category_name
# 0         1001          Political
# 1         1002          Card Game
# 2         1008           Nautical
# 3         1009  Abstract Strategy
# 4         1010            Fantasy

# %%
type_df = pd.read_csv(type_file)
type_df
# Out:
#     bgg_id             name
# 0     4415            Amiga
# 1     4420     Commodore 64
# 2     4664         War Game
# 3     4665  Children's Game
# 4     4666    Abstract Game
# 5     4667     Customizable
# 6     4781           Arcade
# 7     4976         Atari ST
# 8     5496         Thematic
# 9     5497    Strategy Game
# 10    5498       Party Game
# 11    5499      Family Game

# %%
type_df = type_df.rename(columns={'bgg_id':'type_id','name':'type_name'})
type_df.head()
# Out:
#    type_id        type_name
# 0     4415            Amiga
# 1     4420     Commodore 64
# 2     4664         War Game
# 3     4665  Children's Game
# 4     4666    Abstract Game

# %%
mechanic_df = pd.read_csv(mechanic_file)
mechanic_df.head()
# Out:
#    bgg_id                 name
# 0    2001        Action Points
# 1    2002       Tile Placement
# 2    2003  Rock-Paper-Scissors
# 3    2004       Set Collection
# 4    2005        Stock Holding

# %%
mechanic_df = mechanic_df.rename(columns={'bgg_id':'mechanic_id','name':'mechanic_name'})
mechanic_df.head()
# Out:
#    mechanic_id        mechanic_name
# 0         2001        Action Points
# 1         2002       Tile Placement
# 2         2003  Rock-Paper-Scissors
# 3         2004       Set Collection
# 4         2005        Stock Holding

# %%
data_file = "../data/bgg_GameItem.csv"
game_item_df = pd.read_csv(data_file)
game_item_df.head()
# Out:
#    bgg_id            name    year game_type designer       artist  \
# 0       1      Die Macher  1986.0      5497        1   12517,4959
# 1       2    Dragonmaster  1981.0      5497     8384        12424
# 2       3         Samurai  1998.0      5497        2        11883
# 3       4  Tal der Könige  1992.0       NaN     8008         2277
# 4       5         Acquire  1964.0      5497        4  12658,18317
#
#                                            publisher  min_players  \
# 0             133,2,2726,15108,39249,11652,5382,8147          3.0
# 1                                              64,20          3.0
# 2  17,133,267,29,7340,7335,41,2973,4617,1391,8291...          2.0
# 3                                                 37          2.0
# 4     92,5,4871,3082,858,2962,5392,4668,38,4622,7107          2.0
#
#    max_players  min_players_rec  ...  stddev_rating  bayes_rating  complexity  \
# 0          5.0              4.0  ...        1.57880       7.11944      4.3245
# 1          4.0              3.0  ...        1.45047       5.79084      1.9630
# 2          4.0              2.0  ...        1.18780       7.24091      2.4879
# 3          4.0              2.0  ...        1.23454       5.68582      2.6667
# 4          6.0              3.0  ...        1.33492       7.14585      2.5038
#
#    language_dependency  bga_id  dbpedia_id  luding_id spielen_id wikidata_id  \
# 0             1.166667     NaN         NaN        NaN        NaN         NaN
# 1                  NaN     NaN         NaN        NaN        NaN         NaN
# 2             1.000000     NaN         NaN        NaN        NaN         NaN
# 3                  NaN     NaN         NaN        NaN        NaN         NaN
# 4             1.090278     NaN         NaN        NaN        NaN         NaN
#
#    wikipedia_id
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
#
# [5 rows x 38 columns]

# %%
cols = ['bgg_id', 'name', 'year', 'game_type', 'min_players', 'max_players', 
        'min_players_best', 'max_players_best', 'min_age', 'min_time', 'max_time', 
        'category', 'mechanic','cooperative', 'rank', 'num_votes', 'avg_rating', 'complexity']

game_item_df = game_item_df[cols].copy()
game_item_df
# Out:
#         bgg_id                     name    year game_type  min_players  \
# 0            1               Die Macher  1986.0      5497          3.0
# 1            2             Dragonmaster  1981.0      5497          3.0
# 2            3                  Samurai  1998.0      5497          2.0
# 3            4           Tal der Könige  1992.0       NaN          2.0
# 4            5                  Acquire  1964.0      5497          2.0
# ...        ...                      ...     ...       ...          ...
# 102320  341055  Iron, Blood, Snow & Mud  2022.0       NaN          2.0
# 102321  341057   Ich spiele Briefträger  1994.0       NaN          1.0
# 102322  341059           Tier Karussell  2001.0       NaN          1.0
# 102323  341060  Affenstarke Zahlenbande  2018.0       NaN          2.0
# 102324  341166   The Plum Island Horror  2021.0       NaN          1.0
#
#         max_players  min_players_best  max_players_best  min_age  min_time  \
# 0               5.0               5.0               5.0     14.0     240.0
# 1               4.0               3.0               4.0     12.0      30.0
# 2               4.0               3.0               3.0     10.0      30.0
# 3               4.0               2.0               4.0     12.0      60.0
# 4               6.0               4.0               4.0     12.0      90.0
# ...             ...               ...               ...      ...       ...
# 102320          2.0               2.0               2.0     14.0      60.0
# 102321          4.0               1.0               4.0      4.0       NaN
# 102322          4.0               1.0               4.0      3.0      20.0
# 102323          4.0               2.0               4.0      6.0      30.0
# 102324          4.0               1.0               4.0      NaN     120.0
#
#         max_time        category                            mechanic  \
# 0          240.0  1021,1026,1001       2916,2080,2012,2072,2040,2020
# 1           30.0       1002,1010                                2009
# 2           60.0       1009,1035       2080,2040,2026,2846,2004,2002
# 3           60.0            1050                 2001,2080,2012,2004
# 4           90.0       1021,1086  2040,2910,2900,2940,2005,2002,2874
# ...          ...             ...                                 ...
# 102320      90.0       1019,1049            2080,2072,2026,2070,2015
# 102321       NaN       1041,1094                                3007
# 102322      25.0       1089,1041                                3007
# 102323      30.0       1041,1094                                2023
# 102324     150.0            1024                                2023
#
#         cooperative    rank  num_votes  avg_rating  complexity
# 0               NaN   296.0     5265.0     7.62063      4.3245
# 1               NaN  3816.0      556.0     6.64334      1.9630
# 2               NaN   217.0    14913.0     7.45017      2.4879
# 3               NaN  5099.0      338.0     6.59769      2.6667
# 4               NaN   279.0    18352.0     7.33757      2.5038
# ...             ...     ...        ...         ...         ...
# 102320          NaN     NaN        NaN         NaN         NaN
# 102321          NaN     NaN        NaN         NaN         NaN
# 102322          NaN     NaN        NaN         NaN         NaN
# 102323          1.0     NaN        NaN         NaN         NaN
# 102324          1.0     NaN        NaN         NaN         NaN
#
# [102325 rows x 18 columns]

# %%
game_item_df.head()
# Out:
#    bgg_id            name    year game_type  min_players  max_players  \
# 0       1      Die Macher  1986.0      5497          3.0          5.0
# 1       2    Dragonmaster  1981.0      5497          3.0          4.0
# 2       3         Samurai  1998.0      5497          2.0          4.0
# 3       4  Tal der Könige  1992.0       NaN          2.0          4.0
# 4       5         Acquire  1964.0      5497          2.0          6.0
#
#    min_players_best  max_players_best  min_age  min_time  max_time  \
# 0               5.0               5.0     14.0     240.0     240.0
# 1               3.0               4.0     12.0      30.0      30.0
# 2               3.0               3.0     10.0      30.0      60.0
# 3               2.0               4.0     12.0      60.0      60.0
# 4               4.0               4.0     12.0      90.0      90.0
#
#          category                            mechanic  cooperative    rank  \
# 0  1021,1026,1001       2916,2080,2012,2072,2040,2020          NaN   296.0
# 1       1002,1010                                2009          NaN  3816.0
# 2       1009,1035       2080,2040,2026,2846,2004,2002          NaN   217.0
# 3            1050                 2001,2080,2012,2004          NaN  5099.0
# 4       1021,1086  2040,2910,2900,2940,2005,2002,2874          NaN   279.0
#
#    num_votes  avg_rating  complexity
# 0     5265.0     7.62063      4.3245
# 1      556.0     6.64334      1.9630
# 2    14913.0     7.45017      2.4879
# 3      338.0     6.59769      2.6667
# 4    18352.0     7.33757      2.5038

# %%
game_item_df = game_item_df.dropna(subset=['game_type','category','mechanic'], inplace=False).copy()

# %%
game_item_df.head()
# Out:
#    bgg_id          name    year game_type  min_players  max_players  \
# 0       1    Die Macher  1986.0      5497          3.0          5.0
# 1       2  Dragonmaster  1981.0      5497          3.0          4.0
# 2       3       Samurai  1998.0      5497          2.0          4.0
# 4       5       Acquire  1964.0      5497          2.0          6.0
# 6       7     Cathedral  1978.0      4666          2.0          2.0
#
#    min_players_best  max_players_best  min_age  min_time  max_time  \
# 0               5.0               5.0     14.0     240.0     240.0
# 1               3.0               4.0     12.0      30.0      30.0
# 2               3.0               3.0     10.0      30.0      60.0
# 4               4.0               4.0     12.0      90.0      90.0
# 6               2.0               2.0      8.0      20.0      20.0
#
#          category                            mechanic  cooperative    rank  \
# 0  1021,1026,1001       2916,2080,2012,2072,2040,2020          NaN   296.0
# 1       1002,1010                                2009          NaN  3816.0
# 2       1009,1035       2080,2040,2026,2846,2004,2002          NaN   217.0
# 4       1021,1086  2040,2910,2900,2940,2005,2002,2874          NaN   279.0
# 6            1009                 2043,2048,2060,2002          NaN  1915.0
#
#    num_votes  avg_rating  complexity
# 0     5265.0     7.62063      4.3245
# 1      556.0     6.64334      1.9630
# 2    14913.0     7.45017      2.4879
# 4    18352.0     7.33757      2.5038
# 6     3266.0     6.52063      1.7978

# %%
game_item_df['category'] = game_item_df['category'].str[:4]
game_item_df['game_type'] = game_item_df['game_type'].str[:4]
game_item_df['mechanic'] = game_item_df['mechanic'].str[:4]

# %%
game_item_df = game_item_df.loc[game_item_df["year"].notnull()].astype({"year":"int32"})

# %%
game_item_df = game_item_df.loc[game_item_df["category"].notnull()].astype({"category":"int32"})
game_item_df = game_item_df.loc[game_item_df["game_type"].notnull()].astype({"game_type":"int32"})
game_item_df = game_item_df.loc[game_item_df["mechanic"].notnull()].astype({"mechanic":"int32"})
game_item_df = game_item_df.loc[game_item_df["cooperative"].notnull()].astype({"cooperative":"bool"})

# %%
game_item_df["min_age"] = game_item_df.loc[game_item_df["min_age"].notnull()].astype({"min_age":"int32"})

# %%
game_item_df.head()
# Out:
#      bgg_id                          name  year  game_type  min_players  \
# 32       34                 Arkham Horror  1987       5496          1.0
# 118     127  Princess Ryan's Star Marines  1997       4664          1.0
# 721     823         The Lord of the Rings  2000       5496          2.0
# 726     828                       Wizards  1982       5496          1.0
# 775     894                     LifeLinks  2000       4665          1.0
#
#      max_players  min_players_best  max_players_best min_age  min_time  \
# 32           8.0               1.0               8.0      34     180.0
# 118          6.0               1.0               6.0     127     120.0
# 721          5.0               4.0               4.0     823      60.0
# 726          6.0               1.0               6.0     828     120.0
# 775          8.0               1.0               8.0     894      10.0
#
#      max_time  category  mechanic  cooperative     rank  num_votes  \
# 32      180.0      1022      2023         True   4362.0      531.0
# 118     120.0      1039      2023         True  19353.0      206.0
# 721      90.0      1022      2023         True    899.0    14479.0
# 726     240.0      1022      2023         True   5838.0      380.0
# 775      10.0      1002      2012         True      NaN        1.0
#
#      avg_rating  complexity
# 32      6.62741      2.3958
# 118     5.32961      2.4583
# 721     6.75152      2.5636
# 726     6.36720      2.9615
# 775    10.00000         NaN

# %%
game_item_df = game_item_df.set_index("bgg_id")
game_item_df.head()
# Out:
#                                 name  year  game_type  min_players  \
# bgg_id
# 34                     Arkham Horror  1987       5496          1.0
# 127     Princess Ryan's Star Marines  1997       4664          1.0
# 823            The Lord of the Rings  2000       5496          2.0
# 828                          Wizards  1982       5496          1.0
# 894                        LifeLinks  2000       4665          1.0
#
#         max_players  min_players_best  max_players_best min_age  min_time  \
# bgg_id
# 34              8.0               1.0               8.0      34     180.0
# 127             6.0               1.0               6.0     127     120.0
# 823             5.0               4.0               4.0     823      60.0
# 828             6.0               1.0               6.0     828     120.0
# 894             8.0               1.0               8.0     894      10.0
#
#         max_time  category  mechanic  cooperative     rank  num_votes  \
# bgg_id
# 34         180.0      1022      2023         True   4362.0      531.0
# 127        120.0      1039      2023         True  19353.0      206.0
# 823         90.0      1022      2023         True    899.0    14479.0
# 828        240.0      1022      2023         True   5838.0      380.0
# 894         10.0      1002      2012         True      NaN        1.0
#
#         avg_rating  complexity
# bgg_id
# 34         6.62741      2.3958
# 127        5.32961      2.4583
# 823        6.75152      2.5636
# 828        6.36720      2.9615
# 894       10.00000         NaN

# %%
game_item_df_clean = game_item_df_clean.reset_index(drop=True)
game_item_df.head()
# Out:
#                            name  year  game_type  min_players  max_players  \
# 0                 Arkham Horror  1987       5496          1.0          8.0
# 1  Princess Ryan's Star Marines  1997       4664          1.0          6.0
# 2         The Lord of the Rings  2000       5496          2.0          5.0
# 3                       Wizards  1982       5496          1.0          6.0
# 4                     LifeLinks  2000       4665          1.0          8.0
#
#    min_players_best  max_players_best min_age  min_time  max_time  category  \
# 0               1.0               8.0      34     180.0     180.0      1022
# 1               1.0               6.0     127     120.0     120.0      1039
# 2               4.0               4.0     823      60.0      90.0      1022
# 3               1.0               6.0     828     120.0     240.0      1022
# 4               1.0               8.0     894      10.0      10.0      1002
#
#    mechanic  cooperative     rank  num_votes  avg_rating  complexity
# 0      2023         True   4362.0      531.0     6.62741      2.3958
# 1      2023         True  19353.0      206.0     5.32961      2.4583
# 2      2023         True    899.0    14479.0     6.75152      2.5636
# 3      2023         True   5838.0      380.0     6.36720      2.9615
# 4      2012         True      NaN        1.0    10.00000         NaN
