# %% [markdown]
# # Notebook to open the GameItem data file, clean it up, and write out a cleaned csv file

# %%
import pandas as pd 
import numpy as np

# %%
# read in the csv file 
data_file = "../data/bgg_GameItem.csv"
game_item_df = pd.read_csv(data_file)
game_item_df.head()
# Out:
#    bgg_id            name    year game_type designer       artist  \
# 0       1      Die Macher  1986.0      5497        1   12517,4959
# 1       2    Dragonmaster  1981.0      5497     8384        12424
# 2       3         Samurai  1998.0      5497        2        11883
# 3       4  Tal der Könige  1992.0       NaN     8008         2277
# 4       5         Acquire  1964.0      5497        4  12658,18317
#
#                                            publisher  min_players  \
# 0             133,2,2726,15108,39249,11652,5382,8147          3.0
# 1                                              64,20          3.0
# 2  17,133,267,29,7340,7335,41,2973,4617,1391,8291...          2.0
# 3                                                 37          2.0
# 4     92,5,4871,3082,858,2962,5392,4668,38,4622,7107          2.0
#
#    max_players  min_players_rec  ...  stddev_rating  bayes_rating  complexity  \
# 0          5.0              4.0  ...        1.57880       7.11944      4.3245
# 1          4.0              3.0  ...        1.45047       5.79084      1.9630
# 2          4.0              2.0  ...        1.18780       7.24091      2.4879
# 3          4.0              2.0  ...        1.23454       5.68582      2.6667
# 4          6.0              3.0  ...        1.33492       7.14585      2.5038
#
#    language_dependency  bga_id  dbpedia_id  luding_id spielen_id wikidata_id  \
# 0             1.166667     NaN         NaN        NaN        NaN         NaN
# 1                  NaN     NaN         NaN        NaN        NaN         NaN
# 2             1.000000     NaN         NaN        NaN        NaN         NaN
# 3                  NaN     NaN         NaN        NaN        NaN         NaN
# 4             1.090278     NaN         NaN        NaN        NaN         NaN
#
#    wikipedia_id
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
#
# [5 rows x 38 columns]

# %%
# drop some obvious columns first 
game_item_df.drop(["designer", "artist", "publisher","family"],axis=1,inplace=True)

# %%
# Keep the columns that have data  
number_valid_data = game_item_df.count()

cols = []
for ia in range(1,len(number_valid_data)):
    if number_valid_data[ia] > 0:
        cols.append(number_valid_data.index[ia])
        print(number_valid_data[ia], number_valid_data.index[ia]) 
game_item_df_col = game_item_df[cols]
game_item_df_col.head()
# Out:
# 102325 name
# 93049 year
# 21870 game_type
# 100466 min_players
# 96919 max_players
# 100466 min_players_rec
# 96919 max_players_rec
# 100466 min_players_best
# 96919 max_players_best
# 79906 min_age
# 930 min_age_rec
# 80922 min_time
# 80922 max_time
# 100245 category
# 86813 mechanic
# 5134 cooperative
# 752 compilation
# 729 compilation_of
# 66709 family
# 4835 implementation
# 3379 integration
# 20828 rank
# 75154 num_votes
# 75137 avg_rating
# 59346 stddev_rating
# 21145 bayes_rating
# 44300 complexity
# 793 language_dependency
#              name    year game_type  min_players  max_players  \
# 0      Die Macher  1986.0      5497          3.0          5.0
# 1    Dragonmaster  1981.0      5497          3.0          4.0
# 2         Samurai  1998.0      5497          2.0          4.0
# 3  Tal der Könige  1992.0       NaN          2.0          4.0
# 4         Acquire  1964.0      5497          2.0          6.0
#
#    min_players_rec  max_players_rec  min_players_best  max_players_best  \
# 0              4.0              5.0               5.0               5.0
# 1              3.0              4.0               3.0               4.0
# 2              2.0              4.0               3.0               3.0
# 3              2.0              4.0               2.0               4.0
# 4              3.0              6.0               4.0               4.0
#
#    min_age  ...                      family  implementation  integration  \
# 0     14.0  ...              10643,34116,91             NaN          NaN
# 1     12.0  ...                        7005            2174          NaN
# 2     10.0  ...  10634,70711,60111,42,28732             NaN          NaN
# 3     12.0  ...            64229,6471,11505             NaN          NaN
# 4     12.0  ...                        4891             NaN          NaN
#
#      rank num_votes  avg_rating  stddev_rating bayes_rating complexity  \
# 0   296.0    5265.0     7.62063        1.57880      7.11944     4.3245
# 1  3816.0     556.0     6.64334        1.45047      5.79084     1.9630
# 2   217.0   14913.0     7.45017        1.18780      7.24091     2.4879
# 3  5099.0     338.0     6.59769        1.23454      5.68582     2.6667
# 4   279.0   18352.0     7.33757        1.33492      7.14585     2.5038
#
#   language_dependency
# 0            1.166667
# 1                 NaN
# 2            1.000000
# 3                 NaN
# 4            1.090278
#
# [5 rows x 28 columns]

# %%
## Normalise the columns for mechanic, type and category to only have 1 x 4 digit value in each

game_item_df['category'] = game_item_df['category'].str[:4]
game_item_df['game_type'] = game_item_df['game_type'].str[:4]
game_item_df['mechanic'] = game_item_df['mechanic'].str[:4]

# %%
game_item_df.count()
# Out:
# bgg_id                 102325
# name                   102325
# year                    93049
# game_type               21870
# min_players            100466
# max_players             96919
# min_players_rec        100466
# max_players_rec         96919
# min_players_best       100466
# max_players_best        96919
# min_age                 79906
# min_age_rec               930
# min_time                80922
# max_time                80922
# category               100245
# mechanic                86813
# cooperative              5134
# compilation               752
# compilation_of            729
# family                  66709
# implementation           4835
# integration              3379
# rank                    20828
# num_votes               75154
# avg_rating              75137
# stddev_rating           59346
# bayes_rating            21145
# complexity              44300
# language_dependency       793
# bga_id                      0
# dbpedia_id                  0
# luding_id                   0
# spielen_id                  0
# wikidata_id                 0
# wikipedia_id                0
# dtype: int64

# %%
#convert the year from float to integer 
game_item_df_col = game_item_df_col.loc[game_item_df_col["year"].notnull()].astype({"year":"int32"})
game_item_df_col.head()
# Out:
#              name  year game_type  min_players  max_players  min_players_rec  \
# 0      Die Macher  1986      5497          3.0          5.0              4.0
# 1    Dragonmaster  1981      5497          3.0          4.0              3.0
# 2         Samurai  1998      5497          2.0          4.0              2.0
# 3  Tal der Könige  1992       NaN          2.0          4.0              2.0
# 4         Acquire  1964      5497          2.0          6.0              3.0
#
#    max_players_rec  min_players_best  max_players_best  min_age  ...  \
# 0              5.0               5.0               5.0     14.0  ...
# 1              4.0               3.0               4.0     12.0  ...
# 2              4.0               3.0               3.0     10.0  ...
# 3              4.0               2.0               4.0     12.0  ...
# 4              6.0               4.0               4.0     12.0  ...
#
#                        family  implementation  integration    rank num_votes  \
# 0              10643,34116,91             NaN          NaN   296.0    5265.0
# 1                        7005            2174          NaN  3816.0     556.0
# 2  10634,70711,60111,42,28732             NaN          NaN   217.0   14913.0
# 3            64229,6471,11505             NaN          NaN  5099.0     338.0
# 4                        4891             NaN          NaN   279.0   18352.0
#
#    avg_rating  stddev_rating bayes_rating complexity language_dependency
# 0     7.62063        1.57880      7.11944     4.3245            1.166667
# 1     6.64334        1.45047      5.79084     1.9630                 NaN
# 2     7.45017        1.18780      7.24091     2.4879            1.000000
# 3     6.59769        1.23454      5.68582     2.6667                 NaN
# 4     7.33757        1.33492      7.14585     2.5038            1.090278
#
# [5 rows x 28 columns]

# %%
# select the rows that have less than three cols with missing data  
temp_df = game_item_df_col.copy()
missing = [] 
for i in range(len(temp_df.index)) :
    missing.append(temp_df.iloc[i].isnull().sum())  
temp_df["missing"] = missing

temp_df = temp_df.loc[temp_df["missing"]<3]
temp_df.drop("missing", axis=1,inplace=True)
temp_df.head()
# Out:
#                                              name  year  min_players  \
# 1  Masmorra: Dungeons of Arcadia - Promo Dice Set  2016          1.0
# 3                Clank! A Deck-Building Adventure  2012          2.0
# 4                                       El Grande  1995          2.0
# 5                    Gloomhaven: Jaws of the Lion  2020          1.0
# 6                              Android: Netrunner  2012          2.0
#
#    max_players  min_age  min_time  max_time  \
# 1          5.0     13.0      20.0      45.0
# 3          4.0     13.0      30.0      60.0
# 4          5.0     12.0      60.0     120.0
# 5          4.0     14.0      30.0     120.0
# 6          2.0     14.0      30.0      60.0
#
#                                             category  num_votes  avg_rating  \
# 1                                         v4SfYtS2Lr        6.0    3.333333
# 3                   KUBCKBkGxV,ZTneo8TaIO,tQGLgwdbYH      363.0    3.814161
# 4                              QAYkTHK1Dd,nuHYRFmMjU      160.0    3.868750
# 5  KUBCKBkGxV,ge8pIhEUGE,yq6hVlbM2R,ZTneo8TaIO,up...       58.0    4.586207
# 6                   PinhJrhnxU,Ef4oYLHNhI,3B3QpKvXD3      229.0    3.689956
#
#        bga_id
# 1  06J5nkYAvF
# 3  07FXm6tX4o
# 4  07sKc1TGJS
# 5  08asLSfoZy
# 6  08q3IWC9lC

# %%
# write out the cleaned dataframe 
temp_df.to_csv("../data/bga_GameItem_clean.csv")
